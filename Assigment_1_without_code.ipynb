# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (8,6)

# %% [markdown]
# ## Exercise 1
# a) Load house sales data from file kc_house_data.csv, print first records.
# b) Print the variable list. Select categorical and numerical variables.
# c) Compute basic statistics of numerical variables. Are all of them meaningful?

# %%
name = "/home/user/Pulpit/pani_ela_data_science/temat1/kc_house_data/kc_house_data.csv"
name_df = pd.read_csv(name)

# %%
name_df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
name_df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
name_df.select_dtypes( include=['int'] ) 
# categorical : waterfront, view, grade, condition, zipcode
# numerical : bedrooms, sqft_living, sqft_lot, sqft_above, sqft_basement, yr_built, yr_reovated, sqft_living15, sqft_lot15
# Out:
#                id  bedrooms  sqft_living  sqft_lot  waterfront  view  \
# 0      7129300520         3         1180      5650           0     0
# 1      6414100192         3         2570      7242           0     0
# 2      5631500400         2          770     10000           0     0
# 3      2487200875         4         1960      5000           0     0
# 4      1954400510         3         1680      8080           0     0
# ...           ...       ...          ...       ...         ...   ...
# 21608   263000018         3         1530      1131           0     0
# 21609  6600060120         4         2310      5813           0     0
# 21610  1523300141         2         1020      1350           0     0
# 21611   291310100         3         1600      2388           0     0
# 21612  1523300157         2         1020      1076           0     0
#
#        condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %% [markdown]
# # categorical : waterfront, view, grade, condition, zipcode, bedrooms
# # numerical : sqft_living, sqft_lot, sqft_above, sqft_basement, yr_built, yr_reovated, sqft_living15, sqft_lot15

# %%
#c)
#Your code:
name_df.describe()


#Hint: Function describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# ## Exercise 2
# Using scatter plot:
# a) Show the relation of square footage and price.
# b) Check how price is influenced by apartment's grade. Find other variables correlated with price.
# c) Check how good apartments are distributed over the city. First, plot zipcode versus price. Then, use apartments coordinates (longitude and lattitude) in order to show where apartments of good grade are located.

# %%
#a)
#Your code:
x = name_df[["sqft_living"]].values
y = name_df[["price"]].values
plt.scatter(x,y)
plt.xlabel("square footage")
plt.ylabel("price")
plt.show()

# %%
#b)
#Your code:
x1 = name_df[["grade"]].values
y1 = name_df[["price"]].values
plt.scatter(x1,y1)

# %%
#c)
#Your code:
x2 = name_df[["zipcode"]].values
y2 = name_df[["price"]].values
plt.scatter(x2,y2)

# %%
#c)
# name_df.grade.unique()
# array([ 7,  6,  8, 11,  9,  5, 10, 12,  4,  3, 13,  1])

a = name_df['long']
b = name_df['lat']
plt.set_cmap('ocean')
plt.scatter(a,b,c=name_df["grade"])

# %% [markdown]
# ## Exercise 3
# a) Create boxplot of apartment's grade versus it's price. Compare with plot 2b).
# b) Create mosaic plot of any two categorical variables.

# %%
type(name_df[["grade"]])
# Out:
# pandas.core.frame.DataFrame

# %%
#a)
#Your code:
name_df.boxplot(by="grade", column="price", grid=False)
plt.ylabel("price")
title_boxplot = ' '
plt.title( title_boxplot )
plt.suptitle('')
plt.show()

# Hint: plt.boxplot
# boxplot jest lepszy niż zwykły scatter, ponieważ szerokość boxa pokazuje nam zróżnicowanie, i stąd też
# ewidentnie widać, że jest tendencja wzrostowa ponieważ zaznaczył średnią.
# to jest taki scatterplot z dołączonymi statystykami

# %%
#b) # box plot of any two categorical variables
# bedrooms & condition
from statsmodels.graphics.mosaicplot import mosaic

#Your code:
#list(np.unique(name_df.condition.to_numpy()))
#Out: [1, 2, 3, 4, 5]
rand = np.random.random
from itertools import product
list1 = list(np.unique(name_df.bedrooms.to_numpy()))
list2 = list(np.unique(name_df.condition.to_numpy()))
tuples = list(product(list1,list2)) 
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
data = pd.Series(rand(65), index=index)
mosaic(data, title='bedrooms')
plt.show()
# wygląda nieco inaczej bo pewnie użyto inej konbinacji 2 kategorii
# szerokość pasków pokazuje względne liczby mieszkań z daną liczbą sypialni

# %% [markdown]
# ## Exercise 4
# "I am interested in the house with 3 bedrooms, 2 bathrooms and 2 floors"
# a) Compute the basic statistics of apartments fulfilling above constraints.
# b) Distinct accepted apartments on any of previously created plots.
# c) Find such apartments with best price to footage ratio.

# %%
#a)
#Your code:

# 2 floors - podejrzewam, że chodzi o to, żeby sqrt_basement =/= 0
# name_df.bathrooms.to_numpy() # =2 
# name_df.bedrooms.to_numpy() # =3
# name_df.sqft_basement.to_numpy() # =/=0
# z całego dataframe wybrać tylko elementy spełniające powyższe warunki
# Nakładam na dataframe kolejne warunki:
war1_df = name_df.loc[name_df['sqft_basement'] > 0]
war2_df = war1_df.loc[war1_df['bathrooms'] == 2]
# Ostatecznie otrzymuję dataframe spełniający wszystkie warunki
war_df = war2_df.loc[war2_df['bedrooms'] == 3]
war_df.describe()

#Hint: pandas.DataFrame.loc
# Out:
#                  id         price  bedrooms  bathrooms  sqft_living  \
# count  3.930000e+02  3.930000e+02     393.0      393.0   393.000000
# mean   4.697554e+09  5.153171e+05       3.0        2.0  1919.895674
# std    2.988768e+09  2.305154e+05       0.0        0.0   476.861087
# min    3.400116e+07  1.580000e+05       3.0        2.0   940.000000
# 25%    2.222900e+09  3.562000e+05       3.0        2.0  1580.000000
# 50%    3.990200e+09  4.905000e+05       3.0        2.0  1840.000000
# 75%    7.579201e+09  6.355000e+05       3.0        2.0  2180.000000
# max    9.834200e+09  2.200000e+06       3.0        2.0  3660.000000
#
#             sqft_lot      floors  waterfront        view   condition  \
# count     393.000000  393.000000       393.0  393.000000  393.000000
# mean    11789.086514    1.173028         0.0    0.264631    3.715013
# std     25766.073774    0.345282         0.0    0.739688    0.772753
# min       700.000000    1.000000         0.0    0.000000    2.000000
# ...

# %%
#b)
#Your code: 

name_df['filtered'] = np.where((name_df['sqft_basement'] > 0) & (name_df['bathrooms'] == 2) & (name_df['bedrooms'] == 3), 30, 4)
#name_df.head()
a = name_df['grade']
b = name_df['price']
plt.set_cmap('flag')
#sizes = [3 if name_df['filtered']==1 else 7]
plt.scatter(a,b,c=name_df["filtered"], s=name_df['filtered'])

# %%
#c)
#Your code:
# best price to footage(="sqft_living") ratio
name_df["ratio"] = name_df['price']/name_df['sqft_living']
best_price = name_df.loc[name_df['ratio'] < 182]
#Hint: .loc, .sort_values(), .index

# %%
name_df['ratio'].describe()
# Out:
# count    21613.000000
# mean       264.156594
# std        110.060793
# min         87.588235
# 25%        182.291667
# 50%        244.644550
# 75%        318.322981
# max        810.138889
# Name: ratio, dtype: float64

# %%
# z powyższego wyniku dowiedziałam się, że najkorzystniejsza cena za jednostkę powierzchni mieszkaniowej to 87$
# Uznajmy, że najlepsze to będą takie, które mieszczą się w pierwszym kwartyy czyli <182$
best_price.sort_values(by = 'ratio').head()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 18262  2891000610  20141211T000000  148900.0         4       1.75
# 3785    723049156  20140523T000000  149000.0         3       1.00
# 13825  5637200450  20141017T000000  257000.0         5       2.75
# 17197  5111400086  20140512T000000  110000.0         3       1.00
# 1385   3342700465  20150123T000000  250000.0         3       1.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_basement  \
# 18262         1700      6000     1.0           0     0  ...              0
# 3785          1700      8645     1.0           0     0  ...              0
# 13825         2930     10148     2.0           0     0  ...              0
# 17197         1250     53143     1.0           0     0  ...              0
# 1385          2840     10182     1.0           0     0  ...           1330
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...
